# %% [markdown]
# ![](https://i.imgur.com/YX6UATs.png)

# %% [markdown]
# ### **Exercícios de Python - 1**

# %% [markdown]
# 1 - Faça um programa, com uma função que necessite de três argumentos, e que forneça a soma desses três argumentos.

# %%
Argumento1=float(input('Digite um número'))
Argumento2=float(input('Digite um núemro'))
Argumento3=float(input('Digite um número'))
Total=Argumento1+Argumento2+Argumento3
Total
# Out:
# Digite um número3
# Digite um núemro3
# Digite um número3
# 9.0

# %% [markdown]
# 2 - Faça um Programa que peça a temperatura em graus Celsius, transforme e mostre em graus Fahrenheit. \
# *Dica: procure a fórmula para essa conversão na internet*

# %%
Celsius=float(input('Qual a temperatura em Celsius ?'))
Fahrenheit=(9*Celsius+160)/5
Fahrenheit
# Out:
# Qual a temperatura em Celsius ?0
# 32.0

# %% [markdown]
# 3 - Faça um Programa que peça um número inteiro e determine se ele é par ou impar. Dica: utilize o operador módulo (resto da divisão).

# %% [markdown]
# 4 - Faça um programa que peça o tamanho de um arquivo para download (em MB) e a velocidade de um link de Internet (em Mbps), calcule e informe o tempo aproximado de download do arquivo usando este link (em minutos).

# %%
def calcula_tempo():
  Tamanho=float(input('Qual o tamanho do arquivo em MB ?'))
  Velocidade=float(input('Qual a velocidade da conexação em Mbps ?'))
  Temp=(Tamanho*60)/Velocidade
  TempoM=Temp/60
  Tempo=round(TempoM,2)
  return Tempo
calcula_tempo()
# Out:
# Qual o tamanho do arquivo em MB ?100
# Qual a velocidade da conexação em Mbps ?10
# 10.0

# %% [markdown]
# 5 - Faça um programa para a leitura de duas notas parciais de um aluno. O programa deve calcular a média alcançada por aluno e apresentar:
# - A mensagem "Aprovado", se a média alcançada for maior ou igual a sete;
# - A mensagem "Reprovado", se a média for menor do que sete;
# - A mensagem "Aprovado com Distinção", se a média for igual a dez.

# %%
def le_nota():
  nota1=float(input('Nota 1: '))
  nota2=float(input('Nota 2: '))
  media=(nota1+nota2)/2
  if media >= 7:
    print('Aprovado')
  if media <= 7:
    print('Reprovado')
  if media == 10:
    print('Aprovado com disitnção')
le_nota()
# Out:
# Nota 1: 8
# Nota 2: 7
# Aprovado

# %% [markdown]
# Exercícios adaptados de Python Brasil
